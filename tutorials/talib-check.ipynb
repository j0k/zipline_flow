# %%
import numpy
import talib

# %%
# https://mrjbq7.github.io/ta-lib/

# %%
close = numpy.random.random(100)

# %%
import pandas as pd
# %matplotlib inline

# %%
pd.DataFrame(close).plot()

# %%
output = talib.SMA(close)
pd.DataFrame(output).plot()

# %%
pd.DataFrame(output).plot()

# %%
from talib import MA_Type

upper, middle, lower = talib.BBANDS(close, matype=MA_Type.T3)

# %%
pd.DataFrame({"u":upper, "m":middle, "l":lower}).plot()

# %%
l = []

# %%
type(l) == list
# Out:
# True

# %%
o1 = {'count': '1', 'title': 'dfsdf', 'freq': 'freq_1h'}

# %%
"Skill: {title}\nFrequency:{freq}\nTODO:{count}".format(**o1, count=30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-4c3308632aad> in <module>()
# ----> 1 "Skill: {title}\nFrequency:{freq}\nTODO:{count}".format(**o1, count=30)
#
# TypeError: format() got multiple values for keyword argument 'count'

# %%
import time

# %%
time.time()
# Out:
# 1545612614.035453
